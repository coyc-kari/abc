# %%
import pandas as pd

# %%
avc = df = pd.read_parquet('~/Final_project_MLfr_team5/data/processed/rl_feature_dataset.parquet')

# %%
avc
# Out:
#                            ts  spot_open  spot_high  spot_low  spot_close  \
# 0   2024-03-30 00:00:00+00:00    69846.2    70331.0   69528.1     69570.9
# 1   2024-03-31 00:00:00+00:00    69578.4    71349.0   69553.4     71264.5
# 2   2024-04-01 00:00:00+00:00    71257.7    71274.8   68039.1     69653.0
# 3   2024-04-02 00:00:00+00:00    69653.0    69677.5   64597.5     65482.9
# 4   2024-04-03 00:00:00+00:00    65473.1    66890.9   64455.7     65959.2
# ..                        ...        ...        ...       ...         ...
# 725 2026-03-25 00:00:00+00:00    70556.5    72016.4   70413.8     71333.1
# 726 2026-03-26 00:00:00+00:00    71329.1    71438.7   68157.2     68816.7
# 727 2026-03-27 00:00:00+00:00    68820.6    69174.2   65554.1     66409.4
# 728 2026-03-28 00:00:00+00:00    66409.4    67291.4   65928.2     66391.1
# 729 2026-03-29 00:00:00+00:00    66384.4    67130.6   64997.2     66015.1
#
#      spot_volume  fut_open  fut_high  fut_low  fut_close  ...  above_sma_50  \
# ...
